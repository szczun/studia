# %%
import numpy as np

# %%
data = np.loadtxt("diffFeo.x_y")
_2theta = data[:, 0]
intensity = data[:, 1]
# Out:
# array([10.   , 10.01 , 10.02 , ..., 79.976, 79.986, 79.996])

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(1, (20, 6))
plt.plot(_2theta, intensity, color = 'red')
plt.xlabel(r"2$\theta$ [$^\circ$]", fontsize = 15)
plt.xticks(fontsize = 15)
plt.yticks(fontsize = 15)
plt.ylabel("Intensywność", fontsize = 15)
plt.text(x = 35.276, y = 24865.3, s = "111")
plt.text(x = 41.064, y = 37137.309, s = "200")
plt.text(x = 59.789, y = 21500.646, s = "220")
plt.text(x = 71.678, y = 9550.275, s = "311")
plt.text(x = 75.445, y = 6624.592, s = "222")

plt.grid(True)
